# %% [markdown]
# # Cosmic Intelligence Lab
#
# ## Deep Galaxy Explorer — Study 001
#
# ### Notebook 00 — Environment Check
#
# **Purpose**
#
# Verify that the Cosmic Intelligence Lab environment is correctly configured for astronomical image analysis and AI research.
#
# **Author:** Glenn Lindsey
#
# **Date:** July 2026

# %%
import platform
import sys
import os

print("=" * 60)
print("Cosmic Intelligence Lab")
print("=" * 60)

print(f"Python: {sys.version}")
print(f"Platform: {platform.platform()}")
print(f"Working Directory: {os.getcwd()}")
# Out:
# ...
# Cosmic Intelligence Lab
# ...
# Python: 3.12.13 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:38:16) [GCC 14.3.0]
# Platform: Linux-6.17.0-35-generic-x86_64-with-glibc2.39
# Working Directory: /home/glenn/Projects/CosmicIntelligenceLab/notebooks

# %%
import torch

print(f"PyTorch Version : {torch.__version__}")
print(f"CUDA Available  : {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA Version    : {torch.version.cuda}")
    print(f"GPU             : {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch Version : 2.5.1+cu121
# CUDA Available  : True
# CUDA Version    : 12.1
# GPU             : NVIDIA GeForce RTX 3050

# %%
import numpy as np
import pandas as pd
import matplotlib
import astropy
import astroquery
import photutils
import sklearn

print(f"NumPy      : {np.__version__}")
print(f"Pandas     : {pd.__version__}")
print(f"Matplotlib : {matplotlib.__version__}")
print(f"Astropy    : {astropy.__version__}")
print(f"Astroquery : {astroquery.__version__}")
print(f"Photutils  : {photutils.__version__}")
print(f"Scikit-Learn: {sklearn.__version__}")
# Out:
# NumPy      : 2.5.0
# Pandas     : 3.0.3
# Matplotlib : 3.11.0
# Astropy    : 8.0.0
# Astroquery : 0.4.11
# Photutils  : 3.0.0
# Scikit-Learn: 1.9.0

# %%
from pathlib import Path

project_root = Path.cwd().parent

folders = [
    "data",
    "docs",
    "figures",
    "models",
    "notebooks",
    "papers",
    "results",
    "src",
    "website",
]

print("Project Structure Check")
print("-" * 30)

for folder in folders:
    path = project_root / folder
    print(f"{folder:12} {'✓' if path.exists() else '✗'}")
# Out:
# Project Structure Check
# ------------------------------
# data         ✓
# docs         ✓
# figures      ✓
# models       ✓
# notebooks    ✓
# papers       ✓
# results      ✓
# src          ✓
# website      ✓

# %%
from datetime import datetime

print("=" * 60)
print("Notebook Status")
print("=" * 60)
print("Status : PASS")
print("Completed:", datetime.now().strftime("%Y-%m-%d %H:%M"))
# Out:
# ...
# Notebook Status
# ...
# Status : PASS
# Completed: 2026-07-09 17:16

# %%
import subprocess

subprocess.run(
    "conda env export --no-builds > ../environment.yml",
    shell=True
)

print("environment.yml updated")
# Out:
# environment.yml updated
