# %% [markdown]
# # Cosmic Intelligence Lab
#
# ## Deep Galaxy Explorer — Study 001
#
# ### Notebook 002 — Download First Hubble Observation
#
# ---
#
# ### Research Question
#
# How can we retrieve, verify, and store a specific Hubble observation for later AI analysis?
#
# ---
#
# ### Objectives
#
# - Select a Hubble observation
# - Retrieve its associated data products
# - Download one FITS image
# - Store it in `data/raw`
# - Verify the download

# %%
# Cell 1A =============================

from astropy.table import Table

obs = Table.read("../data/catalogs/hudf_search.ecsv",
                 format="ascii.ecsv")

# %%
# Cell 2 — Import Required Libraries ===========

from pathlib import Path

from astropy.table import Table
from astroquery.mast import Observations

# %%
# Cell 3 — Set Project Directories ===============

data_dir = Path("../data/raw")

print(data_dir.resolve())
# Out:
# /home/glenn/Projects/CosmicIntelligenceLab/data/raw

# %%
# Cell 4 - Load Saved Search Results ===============

obs = Table.read(
    "../data/catalogs/hudf_search.ecsv",
    format="ascii.ecsv"
)

print(f"Loaded {len(obs)} observations.")
# Out:
# Loaded 5212 observations.

# %%
# Cell 5 - Select HUDF-DEEP-WFC3 ====================

hudf = obs[obs["target_name"] == "HUDF-DEEP-WFC3"]

print(f"Found {len(hudf)} observations")

hudf[:10]
# Out:
# Found 426 observations
# <Table length=10>
# intentType obs_collection provenance_name ...   objID1   distance
#   str11         str3            str8      ...   str10    float64
# ---------- -------------- --------------- ... ---------- --------
#    science            HST          CALWF3 ... 1131633892      0.0
#    science            HST         HAP-SVM ... 1154418859      0.0
#    science            HST         HAP-SVM ... 1154037505      0.0
#    science            HST          CALWF3 ... 1128230637      0.0
#    science            HST         HAP-SVM ... 1154410383      0.0
#    science            HST          CALWF3 ... 1136715459      0.0
#    science            HST         HAP-SVM ... 1153933108      0.0
#    science            HST         HAP-SVM ... 1153937692      0.0
#    science            HST         HAP-SVM ... 1153933177      0.0
#    science            HST         HAP-SVM ... 1153933236      0.0

# %%
# Cell 5a - Inspect HUDF Observations =========================

hudf["obsid", "obs_id", "instrument_name", "filters"][:20]
# Out:
# <Table length=20>
#   obsid                 obs_id              instrument_name  filters
#    str9                 str48                    str13        str14
# --------- --------------------------------- --------------- ---------
#  24804082                         ibp339020         WFC3/IR     F105W
# 163216819 hst_17073_08_wfc3_ir_total_iey608         WFC3/IR detection
#  26553638 hst_12498_51_wfc3_ir_total_ibp351         WFC3/IR detection
#  24804093                         ibp350020         WFC3/IR     F140W
# 162896929 hst_17073_15_wfc3_ir_total_iey615         WFC3/IR detection
#  24804061                         ibp318020         WFC3/IR     F105W
#  26513951 hst_11563_27_wfc3_ir_total_ib5x27         WFC3/IR detection
#  26514303 hst_11563_1f_wfc3_ir_f160w_ib5x1f         WFC3/IR     F160W
#  26513597 hst_11563_0a_wfc3_ir_f105w_ib5x0a         WFC3/IR     F105W
#  26513598 hst_11563_06_wfc3_ir_f105w_ib5x06         WFC3/IR     F105W
#  26514282 hst_11563_04_wfc3_ir_f105w_ib5x04         WFC3/IR     F105W
#  26552861 hst_12498_57_wfc3_ir_total_ibp357         WFC3/IR detection
#  26513944 hst_11563_25_wfc3_ir_total_ib5x25         WFC3/IR detection
#  24796925                         ib5x25020         WFC3/IR     F160W
#  24804083                         ibp340020         WFC3/IR     F105W
#  26553499 hst_12498_43_wfc3_ir_f105w_ibp343         WFC3/IR     F105W
#  24804079                         ibp336020         WFC3/IR     F105W
#  24796889                         ib5x01020         WFC3/IR     F105W
#  24804090                         ibp347020         WFC3/IR     F105W
#  24796935                         ib5x2f020         WFC3/IR     F160W

# %%
# Cell 6 - Select First Science Observation ==================

one_obs = hudf[7:8]

print(one_obs)
print(f"\nSelected observation: {len(one_obs)}")
# Out:
# intentType obs_collection provenance_name ... wave_max   objID1   distance
# ---------- -------------- --------------- ... -------- ---------- --------
#    science            HST         HAP-SVM ...   1692.4 1153937692      0.0
#
# Selected observation: 1

# %%
# Cell 7 - Retrieve Products ========================

products = Observations.get_product_list(one_obs)

print(f"Products found: {len(products)}")
# Out:
# Products found: 69

# %%
# Cell 8 - Inspect Available Products ==========================

products[
    "productFilename",
    "productSubGroupDescription",
    "productType",
    "size"
][:25]
# Out:
# <Table length=25>
#     productFilename     productSubGroupDescription productType    size
#          str50                    str11                str9      int64
# ----------------------- -------------------------- ----------- ---------
# ib5x1fetq_flt_hlet.fits                   FLT_HLET   AUXILIARY      8640
#      ib5x1fetq_ima.fits                        IMA   AUXILIARY 168261120
#      ib5x1fetq_spt.fits                        SPT   AUXILIARY   1226880
#      ib5x1fetq_trl.fits                        TRL   AUXILIARY     28800
#       ib5x1fetq_log.txt                        LOG        INFO      7874
#       ib5x1fetq_raw.jpg                         --     PREVIEW    253109
#       ib5x1fetq_flt.jpg                         --     PREVIEW    278897
#      ib5x1fetq_flt.fits                        FLT     SCIENCE  16608960
#      ib5x1fetq_raw.fits                        RAW     SCIENCE  34027200
#                     ...                        ...         ...       ...
#       ib5x1fewq_flt.jpg                         --     PREVIEW    279452
#      ib5x1fewq_flt.fits                        FLT     SCIENCE  16608960
#      ib5x1fewq_raw.fits                        RAW     SCIENCE  34027200
# ib5x1ff0q_flt_hlet.fits                   FLT_HLET   AUXILIARY      8640
#      ib5x1ff0q_ima.fits                        IMA   AUXILIARY 168261120
#      ib5x1ff0q_spt.fits                        SPT   AUXILIARY   1226880
#      ib5x1ff0q_trl.fits                        TRL   AUXILIARY     28800
#       ib5x1ff0q_log.txt                        LOG        INFO      7543
#       ib5x1ff0q_raw.jpg                         --     PREVIEW    253771
#       ib5x1ff0q_flt.jpg                         --     PREVIEW    278089

# %%
# Cell 9 - Select the FLT Product =============================

flt = products[
    products["productSubGroupDescription"] == "FLT"
]

print(f"FLT products found: {len(flt)}")

flt["productFilename", "size"]
# Out:
# FLT products found: 8
# <Table length=8>
#               productFilename                  size
#                    str50                      int64
# -------------------------------------------- --------
#                           ib5x1fetq_flt.fits 16608960
#                           ib5x1fewq_flt.fits 16608960
#                           ib5x1ff0q_flt.fits 16608960
#                           ib5x1ff3q_flt.fits 16608960
# hst_11563_1f_wfc3_ir_f160w_ib5x1ff3_flt.fits 16623360
# hst_11563_1f_wfc3_ir_f160w_ib5x1ff0_flt.fits 16623360
# hst_11563_1f_wfc3_ir_f160w_ib5x1fet_flt.fits 16623360
# hst_11563_1f_wfc3_ir_f160w_ib5x1few_flt.fits 16623360

# %%
manifest = Observations.download_products(
    flt[:1],
    download_dir="../data/raw",
    mrp_only=False
)

manifest
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/ib5x1fetq_flt.fits to ../data/raw/mastDownload/HST/ib5x1fetq/ib5x1fetq_flt.fits ... [Done]
# <Table length=1>
#                         Local Path                         Status  ...  URL
#                           str57                             str8   ... object
# --------------------------------------------------------- -------- ... ------
# ../data/raw/mastDownload/HST/ib5x1fetq/ib5x1fetq_flt.fits COMPLETE ...   None

# %%
# Cell 11 - Verify Download =========================

from pathlib import Path

fits_file = Path("../data/raw/mastDownload/HST/ib5x1fetq/ib5x1fetq_flt.fits")

print(f"Exists : {fits_file.exists()}")

if fits_file.exists():
    print(f"Size   : {fits_file.stat().st_size:,} bytes")
    print(f"File   : {fits_file.name}")
# Out:
# Exists : True
# Size   : 16,608,960 bytes
# File   : ib5x1fetq_flt.fits

# %%
# Cell 12 - Notebook Status =========================

from datetime import datetime

print("=" * 60)
print("Notebook Status")
print("=" * 60)
print("Status    : PASS")
print("Notebook  : 02_download_first_observation.ipynb")
print("Completed :", datetime.now().strftime("%Y-%m-%d %H:%M"))

print("\nFirst Hubble FITS image successfully downloaded.")
# Out:
# ============================================================
# Notebook Status
# ============================================================
# Status    : PASS
# Notebook  : 02_download_first_observation.ipynb
# Completed : 2026-07-10 19:53
#
# First Hubble FITS image successfully downloaded.
